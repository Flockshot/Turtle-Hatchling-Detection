# %%
# !pip install roboflow
# !pip install ultralytics==8.0.196
# Out:
# ...
#   Using cached ultralytics-8.0.196-py3-none-any.whl (631 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
# %cd {HOME}

from roboflow import Roboflow
from ultralytics import YOLO
rf = Roboflow(api_key="") # add api key

#project = rf.workspace("hatchlings-xw8eh").project("turtle-hatchlings-detection")
project = rf.workspace("hatchlings-xw8eh").project("coco-and-turtle-manual")

dataset = project.version(1).download("yolov8")
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to coco-and-turtle-manual-1 in yolov8:: 100%|██████████| 12368/12368 [00:01<00:00, 6912.43it/s]

# %%
# %cd {HOME}
from ultralytics import YOLO
#model = YOLO('yolov8n.yaml')
model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights

#results = model.train(data='/content/Turtle-Hatchlings-Detection-1/data.yaml', epochs=20)
#results = model.train(data='coco128.yaml')

results = model.train(data='/content/coco-and-turtle-manual-1/data.yaml', epochs=100)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
from ultralytics import YOLO
model = YOLO("coco-turtle-300-2.pt")
print("Test")

metrics = model.val()  # no arguments needed, dataset and settings remembered
print(metrics.box.map) # map50-95
print(metrics.box.map50) # map50
print(metrics.box.map75)  # map75
print(metrics.box.maps)   # a list contains map50-95 of each category
# Out:
# Test
# Ultralytics YOLOv8.2.29 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8n summary (fused): 168 layers, 3083096 parameters, 0 gradients, 8.4 GFLOPs
# val: Scanning /content/coco-and-turtle-manual-1/valid/labels.cache... 376 images, 3 backgrounds, 0 corrupt: 100%|██████████| 376/376 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 31, len(boxes) = 1626. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 24/24 [00:07<00:00,  3.30it/s]
# ...

# %%
# Install and update Ultralytics and Ray Tune packages
# !pip install -U ultralytics "ray[tune]"
# !pip install -U ultralytics "ray[tune]<=2.9.3"

# Optionally install W&B for logging
# !pip install wandb

# %%
from ultralytics import YOLO
#model = YOLO('yolov8n.yaml')

model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights
model.tune(data='coco-and-turtle-manual-1/data.yaml', epochs=30, iterations=300, optimizer='AdamW', plots=False, save=False, val=False)

# %%
from ultralytics import YOLO
import ultralytics
import torch

torch.cuda.set_device(0) # Set to your desired GPU number
print(torch.cuda.is_available())

ultralytics.checks()
# Load a YOLOv8n model
model = YOLO('yolov8n.pt')

# Start tuning hyperparameters for YOLOv8n training on the COCO8 dataset
result_grid = model.tune(data='/content/coco-and-turtle-manual-1/data.yaml', use_ray=True, gpu_per_trial=1)
import pickle

with open('saved_results.pkl', 'wb') as f:
    pickle.dump(result_grid, f)

# %%
import matplotlib.pyplot as plt

experiment_path = f"{storage_path}/{exp_name}"
print(f"Loading results from {experiment_path}...")

restored_tuner = tune.Tuner.restore(experiment_path, trainable=train_mnist)
result_grid = restored_tuner.get_results()

for result in result_grid:
    plt.plot(result.metrics_dataframe["training_iteration"], result.metrics_dataframe["mean_accuracy"], label=f"Trial {i}")

plt.xlabel('Training Iterations')
plt.ylabel('Mean Accuracy')
plt.legend()
plt.show()
